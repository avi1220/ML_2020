# %%
import pandas as pd 
import numpy as np

df=pd.read_csv('baseball.csv')
df.head()

#input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts,Stolen Bases,
 #   Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves,  Errors
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
# W      30 non-null int64
# R      30 non-null int64
# AB     30 non-null int64
# H      30 non-null int64
# 2B     30 non-null int64
# 3B     30 non-null int64
# HR     30 non-null int64
# BB     30 non-null int64
# SO     30 non-null int64
# SB     30 non-null int64
# RA     30 non-null int64
# ER     30 non-null int64
# ERA    30 non-null float64
# CG     30 non-null int64
# SHO    30 non-null int64
# SV     30 non-null int64
# E      30 non-null int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.lineplot(x=df["HR"],y=df["W"],data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.lineplot(x=df["R"],y=df["W"],data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.lineplot(x=df["H"],y=df["W"],data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.hist(x="W" ,bins=10,data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
corr_hmap=df.corr()
plt.figure(figsize=(11,9))
sns.heatmap(corr_hmap,annot=True)
plt.show()

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
x = df[['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
       'ERA', 'CG', 'SHO', 'SV', 'E']] .values
y = df['W'].values

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
from sklearn.preprocessing import StandardScaler

sc=StandardScaler()

x=sc.fit_transform(x)
x
# Out:
# array([[ 0.61907797,  0.84773126,  1.66368512,  1.42017307,  1.04119304,
#         -0.7872986 , -1.53490242, -2.69762957,  0.91388329, -0.66623393,
#         -0.50511008, -0.50695519, -0.5398062 , -0.81462859,  1.67160651,
#         -0.46146963],
#        [ 0.13443166, -0.71109353, -0.97068076,  0.12740339,  1.23580856,
#         -0.24396668, -0.5365919 ,  0.15487844, -0.60182558,  0.16597077,
#          0.24892985,  0.25459752, -0.5398062 ,  0.1728    ,  0.24987932,
#         -0.60719689],
#        [-0.33290586, -1.1152333 , -0.15189137,  1.58879521, -0.22380785,
#         -0.7233772 ,  1.13914361, -0.89398189,  0.11144918, -0.68033909,
#         -0.75162313, -0.64134684,  2.77264091, -0.32091429, -0.65485616,
#         -1.11724227],
#        [-1.14641931,  0.24152162, -0.40108814, -0.82812203, -0.41842337,
#         -0.8831807 , -1.16053598, -0.16860185, -0.69098493,  0.18007593,
#          0.10392217,  0.05301004,  1.3004422 , -0.56777144, -0.78410408,
#          0.48575751],
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=51)

# %%
lm = LinearRegression()  
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.score(x,y)
# Out:
# 0.8858365658669136

# %%
lm.coef_
# Out:
# array([  7.2481509 ,  -4.7554095 ,   0.85594958,  -0.07213674,
#          1.31542747,  -2.20200723,  -1.23035853,   1.12104247,
#         -0.89313844,  -7.41769014,  48.93485141, -46.75243457,
#          0.6911864 ,   0.5715595 ,   4.49027959,   0.70155817])

# %%
lm.intercept_
# Out:
# 81.95630113948738

# %%
y_pred = lm.predict(x_test)
y_pred
# Out:
# array([ 63.91840869,  93.58088139,  79.65650779,  64.42993854,
#         80.1330356 ,  83.95193639, 103.99021585,  75.19462447,
#         88.47522521,  62.35826025])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df1 = df.head(15)

# %%
df1
# Out:
#    Actual   Predicted
# 0      63   63.918409
# 1      80   93.580881
# 2      81   79.656508
# 3      67   64.429939
# 4      81   80.133036
# 5      79   83.951936
# 6     100  103.990216
# 7      68   75.194624
# 8      83   88.475225
# 9      64   62.358260

# %%
df1.plot(kind='bar',figsize=(10,8))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.253354980930927
# Mean Squared Error: 31.932514660477885
# Root Mean Squared Error: 5.650886183642163

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_pred))
# Out:
# 0.7233843151379254

# %%
from sklearn.model_selection import cross_val_score
from sklearn import linear_model
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring='r2').mean()
# Out:
# 0.04075540667455883

# %%
from sklearn.externals import joblib

joblib.dump(lm,'lm_baseball.pkl')
# Out:
# ['lm_baseball.pkl']
