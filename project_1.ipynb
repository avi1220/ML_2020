# %% [markdown]
# First we check pip is install correctly or not.we will execute "!pip install mysql-connector-python" code.If it is
# satisfied then we import mysql.connector in second step.

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector

# %% [markdown]
# Next we create a new python file and write the following code to test the mysql connection.

# %%
import pandas as pd
con =mysql.connector.connect(
    host="localhost",port=3306,user="root",password="895332",database="stud")

# %% [markdown]
# By using pandas query,fetch the data of students marks in notebook. This process is known as data mining

# %%
df=pd.read_sql_query("Select * from MARKS",con)

# %%
df.head()
# Out:
#        name gender         dob  maths  physics  chemistry  english  biology  \
# 0      John      M  05/04/1988     55       45         56       87       21
# 1    Suresh      M  04/05/1987     75       96         78       64       90
# 2    Ramesh      M  25/05/1989     25       54         89       76       95
# 3   Jessica      F  12/08/1990     78       96         86       63       54
# 4  Jennifer      F  02/09/1989     58       96         78       46       96
#
#    economics  history  civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df.tail()
# Out:
#      name gender         dob  maths  physics  chemistry  english  biology  \
# 5    Annu      F  05/04/1988     45       87         52       89       55
# 6   pooja      F  04/05/1987     55       64         61       58       75
# 7  Ritesh      M  25/05/1989     54       76         87       56       25
# 8   Farha      F  12/08/1990     55       63         89       75       78
# 9  Mukesh      M  02/09/1989     96       46         77       83       58
#
#    economics  history  civics
# 5         89       87      52
# 6         58       64      61
# 7         56       76      87
# 8         75       63      89
# 9         83       46      77

# %%
df.shape
# Out:
# (10, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
# name         10 non-null object
# gender       10 non-null object
# dob          10 non-null object
# maths        10 non-null int64
# physics      10 non-null int64
# chemistry    10 non-null int64
# english      10 non-null int64
# biology      10 non-null int64
# economics    10 non-null int64
# history      10 non-null int64
# civics       10 non-null int64
# dtypes: int64(8), object(3)
# memory usage: 1008.0+ bytes

# %% [markdown]
# There is no missng value.

# %%
df.describe()
# Out:
#            maths    physics  chemistry    english    biology  economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          history   civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %% [markdown]
# We can observe max and min, mean mark  in each subject

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#percentage of marks students get in maths..


plt.pie(df['maths'], labels = {'John', 'Suresh', 'Ramesh', 'Jessica', 'Jennifer', 'Annu', 'pooja',
       'Ritesh', 'Farha', 'Mukesh'},
                               
autopct ='% 1.1f %%', radius=3, shadow = True) 
plt.show()

# %%
sns.lineplot(x=df["name"],y=df["maths"],hue='gender',data=df)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#we can see all subject mark get by students 
df.hist(figsize=(20,20))
plt.show()

# %%
from sklearn.externals import joblib

joblib.dump(df,'df.pkl')
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['df.pkl']
